dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 348494455 (332M) [application/x-gtar]
# Saving to: ‘gender.tgz’
#
# gender.tgz          100%[===================>] 332.35M  90.1MB/s    in 3.7s
#
# 2021-06-08 20:16:19 (89.0 MB/s) - ‘gender.tgz’ saved [348494455/348494455]
#
# ./._x_test.npy
# x_test.npy
# ./._x_train.npy
# x_train.npy
# ./._y_test.npy
# y_test.npy
# ./._y_train.npy
# y_train.npy
# Cloning into 'Viola-Jones'...
# remote: Enumerating objects: 149, done.
# remote: Total 149 (delta 0), reused 0 (delta 0), pack-reused 149
# Receiving objects: 100% (149/149), 229.86 KiB | 12.10 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %% [markdown]
# Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageOps, Image

from __future__ import print_function

import keras

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization as BN
from keras.layers import GaussianNoise as GN
from keras.optimizers import SGD

from keras.callbacks import LearningRateScheduler as LRS
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Define batch size, number of epochs and number of classes

# %%
batch_size = 128
epochs = 50
num_classes=2

# %% [markdown]
# Load and prepare data

# %%
# Load 
x_train = np.load('x_train.npy')
x_test = np.load('x_test.npy')

y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')

# Stats
print(x_train.shape)
print(y_train.shape)
print(sum(y_train == 1))
print(sum(y_train == 0))
print("{:.4f}".format(sum(y_train == 1)/y_train.shape[0]))
print(x_test.shape)
print(y_test.shape)
print(sum(y_test == 1))
print(sum(y_test == 0))
print("{:.4f}".format(sum(y_test == 1)/y_test.shape[0]))


## View some images
for i in range(3):
  plt.imshow(x_train[i,:,:,:])
  plt.show()

x_train.astype('float32')
x_test.astype('float32')

## Transforms
x_train = [np.array(Image.fromarray(x, 'RGB').resize((32, 32))) for x in x_train]
x_test = [np.array(Image.fromarray(x, 'RGB').resize((32, 32))) for x in x_test]

y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

## View some proccesed images
for i in range(3):
  plt.imshow(x_train[i])
  plt.show()

x_train = np.array([x / 255 for x in x_train])
x_test = np.array([x / 255 for x in x_test])

x_train = np.array(x_train).astype('float32').astype('float32')
x_test = np.array(x_test).astype('float32').astype('float32')

print(x_train.shape)
print(x_test.shape)

num_classes = 2

y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)
# Out:
# (10585, 100, 100, 3)
# (10585,)
# 2381
# 8204
# 0.2249
# (2648, 100, 100, 3)
# (2648,)
# 596
# 2052
# 0.2251
# (10585, 32, 32, 3)
# (2648, 32, 32, 3)

# %% [markdown]
# Create model, data augmentation etc...

# %% [markdown]
# Data Augmentation with ImageGenerator

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    rotation_range=45,
    vertical_flip=False)

# %% [markdown]
# Define a convolutional block. Batch norm + Gaussian Norm

# %%
def CBGN(model,filters,ishape=0):
  if (ishape!=0):
    model.add(Conv2D(filters, (3, 3), padding='same',
                 input_shape=ishape))
  else:
    model.add(Conv2D(filters, (3, 3), padding='same'))
  
  model.add(BN())
  model.add(GN(0.25))
  model.add(Activation('relu'))
  #model.add(Dropout(0.25))
  
  return model

# %% [markdown]
# Define the NN topology

# %%
## DEF NN TOPOLOGY  
model = Sequential()

model=CBGN(model,32,x_train.shape[1:])
model=CBGN(model,32)
model.add(MaxPooling2D(pool_size=(2, 2)))
model=CBGN(model,32)
model=CBGN(model,32)
model.add(MaxPooling2D(pool_size=(2, 2)))
model=CBGN(model,64)
model=CBGN(model,64)
model.add(MaxPooling2D(pool_size=(2, 2)))
model=CBGN(model,64)
model=CBGN(model,64)
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())
model.add(Dense(512))
model.add(BN())
model.add(GN(0.2))
model.add(Dropout(0.15))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 32, 32, 32)        0
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 32, 32, 32)        0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 16, 16, 32)        0
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# gaussian_noise_3 (GaussianNo (None, 16, 16, 32)        0
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 8, 8, 64)          0
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 8, 8, 64)          0
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# gaussian_noise_6 (GaussianNo (None, 4, 4, 64)          0
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# gaussian_noise_7 (GaussianNo (None, 4, 4, 64)          0
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# gaussian_noise_8 (GaussianNo (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_9 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 294,114
# Trainable params: 292,322
# Non-trainable params: 1,792
# _________________________________________________________________

# %% [markdown]
# Define an optimizer

# %%
sgd=SGD(lr=0.1, decay=0.0, momentum=0.0)

def scheduler(epoch):
  if epoch < epochs / 3:
    return 0.1
  elif epoch < epochs / 3 * 2:
    return 0.05
  else:
    return 0.02
set_lr = LRS(scheduler)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# Compile the model, define loss and link the optimizer

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %% [markdown]
# Model training and evaluation

# %%
history=model.fit_generator(datagen.flow(x_train, y_train,batch_size=batch_size),
                            steps_per_epoch=len(x_train) / batch_size, 
                            epochs=epochs,
                            validation_data=(x_test, y_test),
                            callbacks=[set_lr],
                            verbose=1)


score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 82/82 [==============================] - 54s 83ms/step - loss: 0.7013 - accuracy: 0.7172 - val_loss: 0.5438 - val_accuracy: 0.7749
# Epoch 2/50
# 82/82 [==============================] - 5s 64ms/step - loss: 0.5109 - accuracy: 0.7677 - val_loss: 0.6433 - val_accuracy: 0.7606
# Epoch 3/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.4729 - accuracy: 0.7766 - val_loss: 0.7038 - val_accuracy: 0.4777
# Epoch 4/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.4249 - accuracy: 0.8051 - val_loss: 0.5009 - val_accuracy: 0.7870
# Epoch 5/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.4042 - accuracy: 0.8134 - val_loss: 0.3911 - val_accuracy: 0.8229
# Epoch 6/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.4175 - accuracy: 0.8121 - val_loss: 0.4466 - val_accuracy: 0.7647
# Epoch 7/50
# 82/82 [==============================] - 5s 66ms/step - loss: 0.3815 - accuracy: 0.8332 - val_loss: 0.4950 - val_accuracy: 0.7413
# Epoch 8/50
# 82/82 [==============================] - 5s 66ms/step - loss: 0.3617 - accuracy: 0.8437 - val_loss: 0.4127 - val_accuracy: 0.8025
# Epoch 9/50
# 82/82 [==============================] - 6s 66ms/step - loss: 0.3376 - accuracy: 0.8523 - val_loss: 0.4956 - val_accuracy: 0.7681
# Epoch 10/50
# 82/82 [==============================] - 5s 66ms/step - loss: 0.3324 - accuracy: 0.8523 - val_loss: 0.5441 - val_accuracy: 0.8259
# Epoch 11/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2995 - accuracy: 0.8798 - val_loss: 0.2899 - val_accuracy: 0.8788
# Epoch 12/50
# 82/82 [==============================] - 5s 66ms/step - loss: 0.2982 - accuracy: 0.8729 - val_loss: 0.5373 - val_accuracy: 0.7621
# Epoch 13/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2851 - accuracy: 0.8802 - val_loss: 0.2795 - val_accuracy: 0.8784
# Epoch 14/50
# 82/82 [==============================] - 5s 66ms/step - loss: 0.2757 - accuracy: 0.8859 - val_loss: 0.2823 - val_accuracy: 0.8784
# Epoch 15/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2663 - accuracy: 0.8923 - val_loss: 0.2442 - val_accuracy: 0.9022
# Epoch 16/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2702 - accuracy: 0.8872 - val_loss: 0.2413 - val_accuracy: 0.9131
# Epoch 17/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2427 - accuracy: 0.9006 - val_loss: 0.2757 - val_accuracy: 0.8795
# Epoch 18/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2398 - accuracy: 0.8989 - val_loss: 0.2888 - val_accuracy: 0.8761
# Epoch 19/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0.2246 - accuracy: 0.9088 - val_loss: 0.2068 - val_accuracy: 0.9135
# Epoch 20/50
# 82/82 [==============================] - 5s 65ms/step - loss: 0